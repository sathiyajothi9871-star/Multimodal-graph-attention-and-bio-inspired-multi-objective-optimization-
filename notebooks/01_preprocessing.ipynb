# %% [markdown]
# # 01 – Preprocessing NSCLC-Radiomics Data
#
# This notebook runs the full preprocessing pipeline:
#
# - CT & mask loading
# - Resampling to isotropic spacing
# - ROI extraction and resizing
# - Intensity normalization
# - Clinical CSV cleaning and encoding
# - Stratified train/val/test split generation

# %%
from src.data.preprocessing import preprocess_ct_and_save, preprocess_clinical_and_splits

# Run CT pipeline (may take a while depending on dataset size)
preprocess_ct_and_save()

# Process clinical CSV and generate splits
preprocess_clinical_and_splits()
