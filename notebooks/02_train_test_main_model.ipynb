# %% [markdown]
# # 02 – Train and Evaluate Main GAT + 3D CNN Model
#
# This notebook trains the full multimodal model and evaluates it
# on the validation and test sets.

# %%
from src.train.train_gat_mogwo import main as train_main

# Train with MO-GWO (or fixed config if USE_MO_GWO=False)
train_main()

# %%
from src.train.evaluate import main as test_main

# Evaluate best checkpoint on the held-out test set
test_main()
