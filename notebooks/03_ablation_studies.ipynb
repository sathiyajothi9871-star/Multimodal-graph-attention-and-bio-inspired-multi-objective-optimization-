# %% [markdown]
# # 03 – Ablation Studies
#
# This notebook runs a series of ablation experiments:
# - Imaging-only
# - Clinical-only
# - No GAT
# - etc.

# %%
from src.train.ablation import main as ablation_main

ablation_main()
