# %% [markdown]
# # 04 – Explainability and Visualization
#
# This notebook generates:
# - SHAP global and local feature importance plots
# - Integrated Gradients overlays for CT
# - GNNExplainer graphs
# - Calibration curve, probability histograms, accuracy-vs-confidence (additionally via your own code if desired)

# %%
from src.xai.shap_explain import main as shap_main
from src.xai.ig_explain import main as ig_main
from src.xai.gnn_explain import main as gnn_main

shap_main()
ig_main()
gnn_main()
